# %%
# https://sadanand-singh.github.io/posts/treebasedmodels/
# https://sadanand-singh.github.io/posts/boostedtrees/

# %%
# %reload_ext autoreload
# %autoreload 2

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.preprocessing import LabelEncoder

# %%
PATH_DATA = './data'
PATH_TRAIN = f'{PATH_DATA}/adult-training.csv'
PATH_TEST = f'{PATH_DATA}/adult-test.csv'

# !head {PATH_TRAIN}
# !wc -l {PATH_TRAIN}
# !head {PATH_TEST}
# !wc -l {PATH_TEST}
# Out:
# 39, State-gov, 77516, Bachelors, 13, Never-married, Adm-clerical, Not-in-family, White, Male, 2174, 0, 40, United-States, <=50K
# 50, Self-emp-not-inc, 83311, Bachelors, 13, Married-civ-spouse, Exec-managerial, Husband, White, Male, 0, 0, 13, United-States, <=50K
# 38, Private, 215646, HS-grad, 9, Divorced, Handlers-cleaners, Not-in-family, White, Male, 0, 0, 40, United-States, <=50K
# 53, Private, 234721, 11th, 7, Married-civ-spouse, Handlers-cleaners, Husband, Black, Male, 0, 0, 40, United-States, <=50K
# 28, Private, 338409, Bachelors, 13, Married-civ-spouse, Prof-specialty, Wife, Black, Female, 0, 0, 40, Cuba, <=50K
# 37, Private, 284582, Masters, 14, Married-civ-spouse, Exec-managerial, Wife, White, Female, 0, 0, 40, United-States, <=50K
# 49, Private, 160187, 9th, 5, Married-spouse-absent, Other-service, Not-in-family, Black, Female, 0, 0, 16, Jamaica, <=50K
# 52, Self-emp-not-inc, 209642, HS-grad, 9, Married-civ-spouse, Exec-managerial, Husband, White, Male, 0, 0, 45, United-States, >50K
# 31, Private, 45781, Masters, 14, Never-married, Prof-specialty, Not-in-family, White, Female, 14084, 0, 50, United-States, >50K
# 42, Private, 159449, Bachelors, 13, Married-civ-spouse, Exec-managerial, Husband, White, Male, 5178, 0, 40, United-States, >50K
# 32562 ./us-census-data/adult-training.csv
# |1x3 Cross validator
# 25, Private, 226802, 11th, 7, Never-married, Machine-op-inspct, Own-child, Black, Male, 0, 0, 40, United-States, <=50K.
# 38, Private, 89814, HS-grad, 9, Married-civ-spouse, Farming-fishing, Husband, White, Male, 0, 0, 50, United-States, <=50K.
# 28, Local-gov, 336951, Assoc-acdm, 12, Married-civ-spouse, Protective-serv, Husband, White, Male, 0, 0, 40, United-States, >50K.
# 44, Private, 160323, Some-college, 10, Married-civ-spouse, Machine-op-inspct, Husband, Black, Male, 7688, 0, 40, United-States, >50K.
# 18, ?, 103497, Some-college, 10, Never-married, ?, Own-child, White, Female, 0, 0, 30, United-States, <=50K.
# 34, Private, 198693, 10th, 6, Never-married, Other-service, Not-in-family, White, Male, 0, 0, 30, United-States, <=50K.
# 29, ?, 227026, HS-grad, 9, Never-married, ?, Unmarried, Black, Male, 0, 0, 40, United-States, <=50K.
# 63, Self-emp-not-inc, 104626, Prof-school, 15, Married-civ-spouse, Prof-specialty, Husband, White, Male, 3103, 0, 32, United-States, >50K.
# 24, Private, 369667, Some-college, 10, Never-married, Other-service, Unmarried, White, Female, 0, 0, 40, United-States, <=50K.
# 16283 ./us-census-data/adult-test.csv

# %%
columns = ['Age','Workclass','fnlgwt','Education','EdNum','MaritalStatus',
           'Occupation','Relationship','Race','Sex','CapitalGain','CapitalLoss',
           'HoursPerWeek','Country','Income']

df_train = pd.read_csv(PATH_TRAIN, names=columns)
df_test = pd.read_csv(PATH_TEST, names=columns, skiprows=1)

df_train.drop('fnlgwt', axis=1, inplace=True)
df_test.drop('fnlgwt', axis=1, inplace=True)

# %%
df_train.head()
df_train.info()
df_train.describe()
# Out:
#    Age          Workclass   Education  EdNum        MaritalStatus  \
# 0   39          State-gov   Bachelors     13        Never-married
# 1   50   Self-emp-not-inc   Bachelors     13   Married-civ-spouse
# 2   38            Private     HS-grad      9             Divorced
# 3   53            Private        11th      7   Married-civ-spouse
# 4   28            Private   Bachelors     13   Married-civ-spouse
#
#            Occupation    Relationship    Race      Sex  CapitalGain  \
# 0        Adm-clerical   Not-in-family   White     Male         2174
# 1     Exec-managerial         Husband   White     Male            0
# 2   Handlers-cleaners   Not-in-family   White     Male            0
# 3   Handlers-cleaners         Husband   Black     Male            0
# 4      Prof-specialty            Wife   Black   Female            0
#
#    CapitalLoss  HoursPerWeek         Country  Income
# 0            0            40   United-States   <=50K
# 1            0            13   United-States   <=50K
# 2            0            40   United-States   <=50K
# 3            0            40   United-States   <=50K
# 4            0            40            Cuba   <=50K
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 14 columns):
# Age              32561 non-null int64
# Workclass        32561 non-null object
# Education        32561 non-null object
# EdNum            32561 non-null int64
# MaritalStatus    32561 non-null object
# Occupation       32561 non-null object
# Relationship     32561 non-null object
# Race             32561 non-null object
# Sex              32561 non-null object
# CapitalGain      32561 non-null int64
# CapitalLoss      32561 non-null int64
# HoursPerWeek     32561 non-null int64
# Country          32561 non-null object
# Income           32561 non-null object
# dtypes: int64(5), object(9)
# memory usage: 3.5+ MB
#                 Age         EdNum   CapitalGain   CapitalLoss  HoursPerWeek
# count  32561.000000  32561.000000  32561.000000  32561.000000  32561.000000
# mean      38.581647     10.080679   1077.648844     87.303830     40.437456
# std       13.640433      2.572720   7385.292085    402.960219     12.347429
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       28.000000      9.000000      0.000000      0.000000     40.000000
# 50%       37.000000     10.000000      0.000000      0.000000     40.000000
# 75%       48.000000     12.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   4356.000000     99.000000

# %%
def df_fix(df):
    df = df.copy()
    for c in df.columns:
        if df[c].dtype != 'int64':
            df[c] = df[c].replace(' ?', 'Unknown')
            df[c] = df[c].apply(lambda s:s.replace(' ', ''))
            df[c] = df[c].apply(lambda s:s.replace('.', ''))
    # remove columns
    df.drop(['Country', 'Education'], axis=1, inplace=True)
    # bin Age to AgeGroup
    labels = ["{0}-{1}".format(i, i + 9) for i in range(0, 100, 10)]
    df['AgeGroup'] = pd.cut(df.Age, range(0, 101, 10), right=False, labels=labels)
    # bin EdNum to Education
    labels = ["{0}-{1}".format(i, i + 4) for i in range(0, 20, 5)]
    df['Education'] = pd.cut(df.EdNum, range(0, 21, 5), right=False, labels=labels)
    # remove columns
    df.drop(['Age', 'EdNum'], axis=1, inplace=True)
    return df

df_train = df_fix(df_train)
df_test = df_fix(df_test)

df_train.Income.value_counts()
df_test.Income.value_counts()
# Out:
# <=50K    24720
# >50K      7841
# Name: Income, dtype: int64
# <=50K    12435
# >50K      3846
# Name: Income, dtype: int64

# %%
df_train.head()
df_test.head()
# Out:
#           Workclass       MaritalStatus         Occupation   Relationship  \
# 0         State-gov       Never-married       Adm-clerical  Not-in-family
# 1  Self-emp-not-inc  Married-civ-spouse    Exec-managerial        Husband
# 2           Private            Divorced  Handlers-cleaners  Not-in-family
# 3           Private  Married-civ-spouse  Handlers-cleaners        Husband
# 4           Private  Married-civ-spouse     Prof-specialty           Wife
#
#     Race     Sex  CapitalGain  CapitalLoss  HoursPerWeek Income AgeGroup  \
# 0  White    Male         2174            0            40  <=50K    30-39
# 1  White    Male            0            0            13  <=50K    50-59
# 2  White    Male            0            0            40  <=50K    30-39
# 3  Black    Male            0            0            40  <=50K    50-59
# 4  Black  Female            0            0            40  <=50K    20-29
#
#   Education
# 0     10-14
# 1     10-14
# 2       5-9
# 3       5-9
# 4     10-14
#    Workclass       MaritalStatus         Occupation Relationship   Race  \
# 0    Private       Never-married  Machine-op-inspct    Own-child  Black
# 1    Private  Married-civ-spouse    Farming-fishing      Husband  White
# 2  Local-gov  Married-civ-spouse    Protective-serv      Husband  White
# 3    Private  Married-civ-spouse  Machine-op-inspct      Husband  Black
# 4    Unknown       Never-married            Unknown    Own-child  White
#
#       Sex  CapitalGain  CapitalLoss  HoursPerWeek Income AgeGroup Education
# 0    Male            0            0            40  <=50K    20-29       5-9
# 1    Male            0            0            50  <=50K    30-39       5-9
# 2    Male            0            0            40   >50K    20-29     10-14
# 3    Male         7688            0            40   >50K    40-49     10-14
# 4  Female            0            0            30  <=50K    10-19     10-14

# %%
df_train.columns
len(df_train.columns)
df_train.info()
# Out:
# Index(['Workclass', 'MaritalStatus', 'Occupation', 'Relationship', 'Race',
#        'Sex', 'CapitalGain', 'CapitalLoss', 'HoursPerWeek', 'Income',
#        'AgeGroup', 'Education'],
#       dtype='object')
# 12
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 12 columns):
# Workclass        32561 non-null object
# MaritalStatus    32561 non-null object
# Occupation       32561 non-null object
# Relationship     32561 non-null object
# Race             32561 non-null object
# Sex              32561 non-null object
# CapitalGain      32561 non-null int64
# CapitalLoss      32561 non-null int64
# HoursPerWeek     32561 non-null int64
# Income           32561 non-null object
# AgeGroup         32561 non-null category
# Education        32561 non-null category
# dtypes: category(2), int64(3), object(7)
# memory usage: 2.5+ MB

# %%
categorical = [
    'AgeGroup',
    'Education',
    'Workclass',
    'MaritalStatus',
    'Occupation',
    'Relationship',
    'Race',
    'Sex',
    'Income'
]

# def to_label(dataframe, categorical=None):
#     from sklearn.preprocessing import LabelEncoder
#     df = dataframe if categorical is None else dataframe[categorical]
#     return df.apply(LabelEncoder().fit_transform)

def to_categorical(dataframe, columns):
    df = dataframe.copy()
    from sklearn.preprocessing import LabelEncoder
    le = LabelEncoder()
    for c in df.columns:
        if c in columns:
            df[c] = le.fit_transform(df[c]).astype('uint16')
    return df

# to_label(df_train, categorical)

# %%
# df_train0 = df_train
# df_train = df_train0
df_train = to_categorical(df_train, categorical)

# %%
df_train.head(10)
df_train.info()
# Out:
#    Workclass  MaritalStatus  Occupation  Relationship  Race  Sex  CapitalGain  \
# 0          6              4           0             1     4    1         2174
# 1          5              2           3             0     4    1            0
# 2          3              0           5             1     4    1            0
# 3          3              2           5             0     2    1            0
# 4          3              2           9             5     2    0            0
# 5          3              2           3             5     4    0            0
# 6          3              3           7             1     2    0            0
# 7          5              2           3             0     4    1            0
# 8          3              4           9             1     4    0        14084
# 9          3              2           3             0     4    1         5178
#
#    CapitalLoss  HoursPerWeek  Income  AgeGroup  Education
# 0            0            40       0         2          1
# 1            0            13       0         4          1
# 2            0            40       0         2          3
# 3            0            40       0         4          3
# 4            0            40       0         1          1
# 5            0            40       0         2          1
# 6            0            16       0         3          3
# 7            0            45       1         4          3
# 8            0            50       1         2          1
# 9            0            40       1         3          1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 12 columns):
# Workclass        32561 non-null uint16
# MaritalStatus    32561 non-null uint16
# Occupation       32561 non-null uint16
# Relationship     32561 non-null uint16
# Race             32561 non-null uint16
# Sex              32561 non-null uint16
# CapitalGain      32561 non-null int64
# CapitalLoss      32561 non-null int64
# HoursPerWeek     32561 non-null int64
# Income           32561 non-null uint16
# AgeGroup         32561 non-null uint16
# Education        32561 non-null uint16
# dtypes: int64(3), uint16(9)
# memory usage: 1.3 MB

# %%
# df_test0 = df_test
# df_test = df_test0
df_test = to_categorical(df_test, categorical)

# %%
df_test.head(10)
df_test.info()
# Out:
#    Workclass  MaritalStatus  Occupation  Relationship  Race  Sex  CapitalGain  \
# 0          3              4           6             3     2    1            0
# 1          3              2           4             0     4    1            0
# 2          1              2          10             0     4    1            0
# 3          3              2           6             0     2    1         7688
# 4          7              4          14             3     4    0            0
# 5          3              4           7             1     4    1            0
# 6          7              4          14             4     2    1            0
# 7          5              2           9             0     4    1         3103
# 8          3              4           7             4     4    0            0
# 9          3              2           2             0     4    1            0
#
#    CapitalLoss  HoursPerWeek  Income  AgeGroup  Education
# 0            0            40       0         1          3
# 1            0            50       0         2          3
# 2            0            40       1         1          1
# 3            0            40       1         3          1
# 4            0            30       0         0          1
# 5            0            30       0         2          3
# 6            0            40       0         1          3
# 7            0            32       1         5          2
# 8            0            40       0         1          1
# 9            0            10       0         4          0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16281 entries, 0 to 16280
# Data columns (total 12 columns):
# Workclass        16281 non-null uint16
# MaritalStatus    16281 non-null uint16
# Occupation       16281 non-null uint16
# Relationship     16281 non-null uint16
# Race             16281 non-null uint16
# Sex              16281 non-null uint16
# CapitalGain      16281 non-null int64
# CapitalLoss      16281 non-null int64
# HoursPerWeek     16281 non-null int64
# Income           16281 non-null uint16
# AgeGroup         16281 non-null uint16
# Education        16281 non-null uint16
# dtypes: int64(3), uint16(9)
# memory usage: 667.9 KB

# %%
y_name = 'Income'
x_names = df_train.columns.drop(y_name).tolist()

y_name
x_names
# Out:
# 'Income'
# ['Workclass',
#  'MaritalStatus',
#  'Occupation',
#  'Relationship',
#  'Race',
#  'Sex',
#  'CapitalGain',
#  'CapitalLoss',
#  'HoursPerWeek',
#  'AgeGroup',
#  'Education']

# %%
y_train = df_train[y_name].values
x_train = df_train.drop(y_name, axis=1).values

y_test = df_test[y_name].values
x_test = df_test.drop(y_name, axis=1).values

# %%
categorical.pop(categorical.index(y_name))
categorical
# Out:
# 'Income'
# ['AgeGroup',
#  'Education',
#  'Workclass',
#  'MaritalStatus',
#  'Occupation',
#  'Relationship',
#  'Race',
#  'Sex']

# %%
x_train
y_train
x_test
y_test
# Out:
# array([[ 6,  4,  0, ..., 40,  2,  1],
#        [ 5,  2,  3, ..., 13,  4,  1],
#        [ 3,  0,  5, ..., 40,  2,  3],
#        ...,
#        [ 3,  6,  0, ..., 40,  4,  3],
#        [ 3,  4,  0, ..., 20,  1,  3],
#        [ 4,  2,  3, ..., 40,  4,  3]])
# array([0, 0, 0, ..., 0, 0, 1], dtype=uint16)
# array([[ 3,  4,  6, ..., 40,  1,  3],
#        [ 3,  2,  4, ..., 50,  2,  3],
#        [ 1,  2, 10, ..., 40,  1,  1],
#        ...,
#        [ 3,  2,  9, ..., 50,  2,  1],
#        [ 3,  0,  0, ..., 40,  3,  1],
#        [ 4,  2,  3, ..., 60,  2,  1]])
# array([0, 0, 1, ..., 0, 0, 1], dtype=uint16)

# %%
import lightgbm as lgb

d_train = lgb.Dataset(x_train, y_train, feature_name=x_names, categorical_feature=categorical)
d_test = lgb.Dataset(x_test, y_test, reference=d_train)

d_train
d_test

# %%
params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': ['binary_logloss', 'auc'],
    
    'seed': 430,
    'max_bin': 255,
    'learning_rate': .05,
    
#     'num_trees': 2000,
    'num_leaves': 127,
#     'min_data_in_leaf': 100,
#     'early_stopping': 100,
    
    'reg_alpha': .001,
    'reg_lambda': 1,

    'bagging_fraction': .9,
    'bagging_freq': 3,
    'feature_fraction': .75,
    
}

scores = lgb.cv(params, d_train, nfold=5, num_boost_round=20, early_stopping_rounds=10)
# Out:
# /home/ggg/.virtualenvs/forest/lib/python3.6/site-packages/lightgbm/basic.py:1040: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')

# %%
pd.DataFrame(scores)
# Out:
#     auc-mean  auc-stdv  binary_logloss-mean  binary_logloss-stdv
# 0   0.896009  0.006250             0.530900             0.000629
# 1   0.906671  0.006418             0.514752             0.001137
# 2   0.911611  0.005704             0.497859             0.001556
# 3   0.912497  0.005982             0.483061             0.001944
# 4   0.912582  0.005979             0.469643             0.002370
# 5   0.912707  0.006031             0.458876             0.002709
# 6   0.914049  0.006069             0.447331             0.003020
# 7   0.914229  0.005916             0.438573             0.003261
# 8   0.913771  0.005732             0.430574             0.003456
# 9   0.913482  0.005938             0.423519             0.003667
# 10  0.912960  0.006048             0.416558             0.003940
# 11  0.913633  0.005877             0.408903             0.004092
# 12  0.914141  0.005892             0.401490             0.004330
# 13  0.914419  0.005982             0.394764             0.004566
# 14  0.914984  0.005967             0.388214             0.004815
# 15  0.915502  0.005903             0.382577             0.004945
# 16  0.915598  0.005961             0.378134             0.005114
# 17  0.915947  0.006099             0.372769             0.005373
# 18  0.916487  0.005966             0.367823             0.005479
# 19  0.916626  0.006101             0.363585             0.005710

# %%
params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': ['binary_logloss', 'auc'],
#     'metric': 'auc',
    
    'seed': 430,
    'learning_rate': 0.01,
    
    'reg_alpha': .001,
    'reg_lambda': 1,

    'bagging_fraction': .9,
    'feature_fraction': .75,
    
}

evals_result = {}
gbm = lgb.train(params, d_train, num_boost_round=3000,
                valid_sets=d_test, valid_names=['test'],
                early_stopping_rounds=100, evals_result=evals_result)

# %%
gbm.best_iteration
gbm.best_score

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
# GridSearchCV(estimator, param_grid, scoring=None, fit_params=None, n_jobs=1,
# iid=True, refit=True, cv=None, verbose=0, pre_dispatch=‘2*n_jobs’,
# error_score=’raise’, return_train_score=’warn’)[

# %%
import itertools
from sklearn.metrics import confusion_matrix
def plot_confusion_matrix(cm, classes, normalize=False):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    cmap = plt.cm.Blues
    title = "Confusion Matrix"
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.around(cm, decimals=3)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
import hyperopt as ho

# %%
# class Foo(object):
#     def __init__(self, features, target
#                 ):
#         params = {
#             'boosting_type': 'gbdt',
#             'objective': 'binary',
#             'metric': ['binary_logloss', 'auc'],
#             'seed': 430,
#         }

#     def f(params_space):

#         lgb.cv(params.update(params_space), )

# %%
# %%time

d_train = lgb.Dataset(x_train, y_train, feature_name=x_names, categorical_feature=categorical, free_raw_data=False)
# d_test = lgb.Dataset(x_test, y_test, reference=d_train)

from functools import partial

def func_cv(params_space):
    params = {
        'boosting_type': 'gbdt',
        'objective': 'binary',
        'metric': 'binary_logloss',
        'seed': 430,
    }
    params.update(params_space)
    scores = lgb.cv(params, d_train, nfold=6)
    return scores


def func_min(fn, space):
    s = fn(space)
    return np.min(s.get('binary_logloss-mean'))


params_space = {
    'max_bin': ho.hp.choice('max_bin', [255, 127, 63]),
    'learning_rate': ho.hp.uniform('learning_rate', .001, .3),
    
    'num_leaves': ho.hp.choice('num_leaves', [127, 63, 31]),
    
    'reg_alpha': ho.hp.uniform('reg_alpha', .005, .2),
    'reg_lambda': ho.hp.uniform('reg_lambda', .1, .6),

#     'bagging_fraction': ho.hp.uniform('bagging_fraction', .5, 1.),
#     'bagging_freq': ho.hp.choice('bagging_freq', [1, 2, 3, 4, 5]),
    
    'feature_fraction': ho.hp.uniform('feature_fraction', .5, 1.),
}

trials = ho.Trials()

best = ho.fmin(
    partial(func_min, func_cv),
    space=params_space,
    algo=ho.tpe.suggest, 
    max_evals=200,
    trials=trials,
    rstate=np.random.RandomState(430)
)

# print(params_space)
# Out:
# /home/ggg/.virtualenvs/forest/lib/python3.6/site-packages/lightgbm/basic.py:1040: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# CPU times: user 30min 1s, sys: 27.9 s, total: 30min 29s
# Wall time: 8min 24s

# %%
from pprint import pprint as pp

params_best = ho.space_eval(params_space, best)
pp(params_best)
pd.DataFrame(func_cv(params_best))
# Out:
# {'feature_fraction': 0.5001306578388296,
#  'learning_rate': 0.2881638907334713,
#  'max_bin': 255,
#  'num_leaves': 31,
#  'reg_alpha': 0.11987032076957657,
#  'reg_lambda': 0.12012820361026232}
# /home/ggg/.virtualenvs/forest/lib/python3.6/site-packages/lightgbm/basic.py:1040: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
#     binary_logloss-mean  binary_logloss-stdv
# 0              0.447102             0.003840
# 1              0.410705             0.004437
# 2              0.376251             0.005511
# 3              0.354867             0.006214
# 4              0.338284             0.006607
# 5              0.327271             0.007305
# 6              0.316971             0.007720
# 7              0.312110             0.008093
# 8              0.307895             0.008175
# 9              0.304836             0.008479
# 10             0.302055             0.008739
# 11             0.297529             0.008949
# 12             0.295785             0.008960
# 13             0.292918             0.009041
# 14             0.290615             0.009285
# 15             0.289723             0.009358
# 16             0.288549             0.009386
# 17             0.287521             0.009334
# 18             0.286057             0.009200
# 19             0.285002             0.009340
# 20             0.283885             0.009153
# 21             0.283654             0.009319
# 22             0.282763             0.009398
# 23             0.281926             0.009386
# 24             0.281575             0.009399
# 25             0.280970             0.009250
# 26             0.280867             0.009281
# 27             0.280595             0.009354
# 28             0.280369             0.009429
# 29             0.280232             0.009537
# ..                  ...                  ...
# 70             0.278906             0.009768
# 71             0.278963             0.009711
# 72             0.278994             0.009660
# 73             0.279031             0.009516
# 74             0.279123             0.009495
# 75             0.279122             0.009527
# 76             0.279270             0.009528
# 77             0.279314             0.009456
# 78             0.279354             0.009466
# 79             0.279438             0.009519
# 80             0.279596             0.009539
# 81             0.279679             0.009572
# 82             0.279658             0.009538
# 83             0.279705             0.009576
# 84             0.279775             0.009508
# 85             0.279979             0.009618
# 86             0.280016             0.009638
# 87             0.280114             0.009580
# 88             0.280147             0.009582
# 89             0.280131             0.009549
# 90             0.280163             0.009549
# 91             0.280219             0.009572
# 92             0.280391             0.009559
# 93             0.280433             0.009566
# 94             0.280490             0.009619
# 95             0.280470             0.009660
# 96             0.280605             0.009634
# 97             0.280566             0.009556
# 98             0.280495             0.009555
# 99             0.280542             0.009502
#
# [100 rows x 2 columns]

# %%
# ho.pyll.stochastic.sample(params_space)
# Out:
# {'feature_fraction': 0.858208745254183,
#  'learning_rate': 0.09931705464961389,
#  'max_bin': 63,
#  'num_leaves': 127,
#  'reg_alpha': 0.04300464190621706,
#  'reg_lambda': 0.2826587492401653}

# %%
# from pprint import pprint as pp
# for t in trials.trials:
#     pp(t)
# Out:
# {'book_time': datetime.datetime(2018, 7, 20, 13, 50, 20, 280000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#           'idxs': {'bagging_fraction': [0],
#                    'bagging_freq': [0],
#                    'feature_fraction': [0],
#                    'learning_rate': [0],
#                    'max_bin': [0],
#                    'num_leaves': [0],
#                    'reg_alpha': [0],
#                    'reg_lambda': [0]},
#           'tid': 0,
#           'vals': {'bagging_fraction': [0.6751659580961454],
#                    'bagging_freq': [2],
#                    'feature_fraction': [0.9664607813406715],
#                    'learning_rate': [0.013456500807992579],
#                    'max_bin': [0],
#                    'num_leaves': [1],
#                    'reg_alpha': [0.11262540945953152],
#                    'reg_lambda': [0.32513724929475074]},
#           'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2018, 7, 20, 13, 50, 22, 593000),
#  'result': {'loss': 0.3374846154796699, 'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 0,
#  'version': 0}
# {'book_time': datetime.datetime(2018, 7, 20, 13, 50, 22, 597000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#           'idxs': {'bagging_fraction': [1],
#                    'bagging_freq': [1],
#                    'feature_fraction': [1],
#                    'learning_rate': [1],
#                    'max_bin': [1],
#                    'num_leaves': [1],
#                    'reg_alpha': [1],
#                    'reg_lambda': [1]},
#           'tid': 1,
#           'vals': {'bagging_fraction': [0.6276589351395263],
#                    'bagging_freq': [0],
#                    'feature_fraction': [0.6523460218581321],
#                    'learning_rate': [0.17084249301858054],
#                    'max_bin': [2],
#                    'num_leaves': [0],
#                    'reg_alpha': [0.005453295290431124],
#                    'reg_lambda': [0.4104451370520603]},
#           'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2018, 7, 20, 13, 50, 25, 59000),
#  'result': {'loss': 0.2847300697883379, 'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 1,
#  'version': 0}
# {'book_time': datetime.datetime(2018, 7, 20, 13, 50, 25, 63000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#           'idxs': {'bagging_fraction': [2],
#                    'bagging_freq': [2],
#                    'feature_fraction': [2],
#                    'learning_rate': [2],
#                    'max_bin': [2],
#                    'num_leaves': [2],
#                    'reg_alpha': [2],
#                    'reg_lambda': [2]},
#           'tid': 2,
#           'vals': {'bagging_fraction': [0.8759475658586514],
#                    'bagging_freq': [2],
#                    'feature_fraction': [0.6114997195609425],
#                    'learning_rate': [0.23644604809054437],
#                    'max_bin': [1],
#                    'num_leaves': [1],
#                    'reg_alpha': [0.03880420802020709],
#                    'reg_lambda': [0.24662707752528454]},
#           'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2018, 7, 20, 13, 50, 27, 425000),
#  'result': {'loss': 0.2808512064897934, 'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 2,
#  'version': 0}
# {'book_time': datetime.datetime(2018, 7, 20, 13, 50, 27, 429000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#           'idxs': {'bagging_fraction': [3],
#                    'bagging_freq': [3],
#                    'feature_fraction': [3],
#                    'learning_rate': [3],
#                    'max_bin': [3],
#                    'num_leaves': [3],
#                    'reg_alpha': [3],
#                    'reg_lambda': [3]},
#           'tid': 3,
#           'vals': {'bagging_fraction': [0.7137609717111265],
#                    'bagging_freq': [3],
#                    'feature_fraction': [0.6109504861002298],
#                    'learning_rate': [0.11277963378189773],
#                    'max_bin': [2],
#                    'num_leaves': [1],
#                    'reg_alpha': [0.1520799561027464],
#                    'reg_lambda': [0.4603416175077981]},
#           'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2018, 7, 20, 13, 50, 29, 771000),
#  'result': {'loss': 0.28247691915118195, 'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 3,
#  'version': 0}
# {'book_time': datetime.datetime(2018, 7, 20, 13, 50, 29, 775000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#           'idxs': {'bagging_fraction': [4],
#                    'bagging_freq': [4],
#                    'feature_fraction': [4],
#                    'learning_rate': [4],
#                    'max_bin': [4],
#                    'num_leaves': [4],
#                    'reg_alpha': [4],
#                    'reg_lambda': [4]},
#           'tid': 4,
#           'vals': {'bagging_fraction': [0.6688439425214983],
#                    'bagging_freq': [0],
#                    'feature_fraction': [0.8626494712986981],
#                    'learning_rate': [0.1137249166095649],
#                    'max_bin': [2],
#                    'num_leaves': [1],
#                    'reg_alpha': [0.05672072789438726],
#                    'reg_lambda': [0.21845388440239996]},
#           'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2018, 7, 20, 13, 50, 31, 745000),
#  'result': {'loss': 0.284401304349668, 'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 4,
#  'version': 0}
# {'book_time': datetime.datetime(2018, 7, 20, 13, 50, 31, 749000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#           'idxs': {'bagging_fraction': [5],
#                    'bagging_freq': [5],
#                    'feature_fraction': [5],
#                    'learning_rate': [5],
#                    'max_bin': [5],
#                    'num_leaves': [5],
#                    'reg_alpha': [5],
#                    'reg_lambda': [5]},
#           'tid': 5,
#           'vals': {'bagging_fraction': [0.935945230432562],
#                    'bagging_freq': [1],
#                    'feature_fraction': [0.7066764987750407],
#                    'learning_rate': [0.20019394143190689],
#                    'max_bin': [0],
#                    'num_leaves': [1],
#                    'reg_alpha': [0.19644570555115307],
#                    'reg_lambda': [0.4070528307225534]},
#           'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2018, 7, 20, 13, 50, 34, 335000),
#  'result': {'loss': 0.2816584221527752, 'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 5,
#  'version': 0}
# {'book_time': datetime.datetime(2018, 7, 20, 13, 50, 34, 339000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#           'idxs': {'bagging_fraction': [6],
#                    'bagging_freq': [6],
#                    'feature_fraction': [6],
#                    'learning_rate': [6],
#                    'max_bin': [6],
#                    'num_leaves': [6],
#                    'reg_alpha': [6],
#                    'reg_lambda': [6]},
#           'tid': 6,
#           'vals': {'bagging_fraction': [0.6596406944815274],
#                    'bagging_freq': [4],
#                    'feature_fraction': [0.7485989882766402],
#                    'learning_rate': [0.24973608212399334],
#                    'max_bin': [2],
#                    'num_leaves': [1],
#                    'reg_alpha': [0.061485641117873094],
#                    'reg_lambda': [0.15836245988029854]},
#           'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2018, 7, 20, 13, 50, 36, 719000),
#  'result': {'loss': 0.28527145154752553, 'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 6,
#  'version': 0}
# {'book_time': datetime.datetime(2018, 7, 20, 13, 50, 36, 723000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#           'idxs': {'bagging_fraction': [7],
#                    'bagging_freq': [7],
#                    'feature_fraction': [7],
#                    'learning_rate': [7],
#                    'max_bin': [7],
#                    'num_leaves': [7],
#                    'reg_alpha': [7],
#                    'reg_lambda': [7]},
#           'tid': 7,
#           'vals': {'bagging_fraction': [0.8920134550284778],
#                    'bagging_freq': [1],
#                    'feature_fraction': [0.6337986035561636],
#                    'learning_rate': [0.23878267864912797],
#                    'max_bin': [2],
#                    'num_leaves': [0],
#                    'reg_alpha': [0.1589114510867068],
#                    'reg_lambda': [0.41641448881133114]},
#           'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2018, 7, 20, 13, 50, 39, 833000),
#  'result': {'loss': 0.2820014775300422, 'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 7,
#  'version': 0}
# {'book_time': datetime.datetime(2018, 7, 20, 13, 50, 39, 837000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#           'idxs': {'bagging_fraction': [8],
#                    'bagging_freq': [8],
#                    'feature_fraction': [8],
#                    'learning_rate': [8],
#                    'max_bin': [8],
#                    'num_leaves': [8],
#                    'reg_alpha': [8],
#                    'reg_lambda': [8]},
#           'tid': 8,
#           'vals': {'bagging_fraction': [0.7595950337422093],
#                    'bagging_freq': [2],
#                    'feature_fraction': [0.6716672047584146],
#                    'learning_rate': [0.1616535563540146],
#                    'max_bin': [2],
#                    'num_leaves': [0],
#                    'reg_alpha': [0.030189302750908687],
#                    'reg_lambda': [0.5190631311272279]},
#           'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2018, 7, 20, 13, 50, 43, 429000),
#  'result': {'loss': 0.283530749576991, 'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 8,
#  'version': 0}
# {'book_time': datetime.datetime(2018, 7, 20, 13, 50, 43, 433000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#           'idxs': {'bagging_fraction': [9],
#                    'bagging_freq': [9],
#                    'feature_fraction': [9],
#                    'learning_rate': [9],
#                    'max_bin': [9],
#                    'num_leaves': [9],
#                    'reg_alpha': [9],
#                    'reg_lambda': [9]},
#           'tid': 9,
#           'vals': {'bagging_fraction': [0.9788922812147409],
#                    'bagging_freq': [0],
#                    'feature_fraction': [0.9453473919212483],
#                    'learning_rate': [0.004306339229595278],
#                    'max_bin': [2],
#                    'num_leaves': [1],
#                    'reg_alpha': [0.05425850153859206],
#                    'reg_lambda': [0.2208543945132627]},
#           'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2018, 7, 20, 13, 50, 47, 493000),
#  'result': {'loss': 0.42922295419395107, 'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 9,
#  'version': 0}
# {'book_time': datetime.datetime(2018, 7, 20, 13, 50, 47, 498000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#           'idxs': {'bagging_fraction': [10],
#                    'bagging_freq': [10],
#                    'feature_fraction': [10],
#                    'learning_rate': [10],
#                    'max_bin': [10],
#                    'num_leaves': [10],
#                    'reg_alpha': [10],
#                    'reg_lambda': [10]},
#           'tid': 10,
#           'vals': {'bagging_fraction': [0.7184150122345748],
#                    'bagging_freq': [3],
#                    'feature_fraction': [0.9661272539560106],
#                    'learning_rate': [0.14805409281334508],
#                    'max_bin': [2],
#                    'num_leaves': [0],
#                    'reg_alpha': [0.1697529201671636],
#                    'reg_lambda': [0.3713539480372994]},
#           'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2018, 7, 20, 13, 50, 52, 233000),
#  'result': {'loss': 0.2873179948610238, 'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 10,
#  'version': 0}
# {'book_time': datetime.datetime(2018, 7, 20, 13, 50, 52, 237000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#           'idxs': {'bagging_fraction': [11],
#                    'bagging_freq': [11],
#                    'feature_fraction': [11],
#                    'learning_rate': [11],
#                    'max_bin': [11],
#                    'num_leaves': [11],
#                    'reg_alpha': [11],
#                    'reg_lambda': [11]},
#           'tid': 11,
#           'vals': {'bagging_fraction': [0.8848633131861249],
#                    'bagging_freq': [3],
#                    'feature_fraction': [0.5869859298458762],
#                    'learning_rate': [0.07850754446190958],
#                    'max_bin': [0],
#                    'num_leaves': [1],
#                    'reg_alpha': [0.09051770664715546],
#                    'reg_lambda': [0.3987857916021047]},
#           'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2018, 7, 20, 13, 50, 54, 875000),
#  'result': {'loss': 0.2816129834377743, 'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 11,
#  'version': 0}
# {'book_time': datetime.datetime(2018, 7, 20, 13, 50, 54, 879000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#           'idxs': {'bagging_fraction': [12],
#                    'bagging_freq': [12],
#                    'feature_fraction': [12],
#                    'learning_rate': [12],
#                    'max_bin': [12],
#                    'num_leaves': [12],
#                    'reg_alpha': [12],
#                    'reg_lambda': [12]},
#           'tid': 12,
#           'vals': {'bagging_fraction': [0.8633604732953879],
#                    'bagging_freq': [3],
#                    'feature_fraction': [0.6420158108708109],
#                    'learning_rate': [0.21230554680744929],
#                    'max_bin': [0],
#                    'num_leaves': [1],
#                    'reg_alpha': [0.07495751592835184],
#                    'reg_lambda': [0.5702764651253737]},
#           'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2018, 7, 20, 13, 50, 59, 54000),
#  'result': {'loss': 0.28295914035119935, 'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 12,
#  'version': 0}
# {'book_time': datetime.datetime(2018, 7, 20, 13, 50, 59, 59000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#           'idxs': {'bagging_fraction': [13],
#                    'bagging_freq': [13],
#                    'feature_fraction': [13],
#                    'learning_rate': [13],
#                    'max_bin': [13],
#                    'num_leaves': [13],
#                    'reg_alpha': [13],
#                    'reg_lambda': [13]},
#           'tid': 13,
#           'vals': {'bagging_fraction': [0.5776365199919382],
#                    'bagging_freq': [3],
#                    'feature_fraction': [0.951689258283693],
#                    'learning_rate': [0.03925200596476429],
#                    'max_bin': [2],
#                    'num_leaves': [0],
#                    'reg_alpha': [0.18978374417306865],
#                    'reg_lambda': [0.33631009368948317]},
#           'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2018, 7, 20, 13, 51, 2, 735000),
#  'result': {'loss': 0.2905336538960239, 'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 13,
#  'version': 0}
# {'book_time': datetime.datetime(2018, 7, 20, 13, 51, 2, 740000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#           'idxs': {'bagging_fraction': [14],
#                    'bagging_freq': [14],
#                    'feature_fraction': [14],
#                    'learning_rate': [14],
#                    'max_bin': [14],
#                    'num_leaves': [14],
#                    'reg_alpha': [14],
#                    'reg_lambda': [14]},
#           'tid': 14,
#           'vals': {'bagging_fraction': [0.5154737634525661],
#                    'bagging_freq': [0],
#                    'feature_fraction': [0.570640203762429],
#                    'learning_rate': [0.03873176580065576],
#                    'max_bin': [1],
#                    'num_leaves': [0],
#                    'reg_alpha': [0.052104235366727036],
#                    'reg_lambda': [0.5931744087884231]},
#           'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2018, 7, 20, 13, 51, 5, 31000),
#  'result': {'loss': 0.2958534801636952, 'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 14,
#  'version': 0}
# {'book_time': datetime.datetime(2018, 7, 20, 13, 51, 5, 36000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#           'idxs': {'bagging_fraction': [15],
#                    'bagging_freq': [15],
#                    'feature_fraction': [15],
#                    'learning_rate': [15],
#                    'max_bin': [15],
#                    'num_leaves': [15],
#                    'reg_alpha': [15],
#                    'reg_lambda': [15]},
#           'tid': 15,
#           'vals': {'bagging_fraction': [0.9171198759710657],
#                    'bagging_freq': [2],
#                    'feature_fraction': [0.7522363132214758],
#                    'learning_rate': [0.26893952696666984],
#                    'max_bin': [0],
#                    'num_leaves': [0],
#                    'reg_alpha': [0.01667615497098003],
#                    'reg_lambda': [0.21339307693731804]},
#           'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2018, 7, 20, 13, 51, 9, 704000),
#  'result': {'loss': 0.2838336316887361, 'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 15,
#  'version': 0}
# {'book_time': datetime.datetime(2018, 7, 20, 13, 51, 9, 709000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#           'idxs': {'bagging_fraction': [16],
#                    'bagging_freq': [16],
#                    'feature_fraction': [16],
#                    'learning_rate': [16],
#                    'max_bin': [16],
#                    'num_leaves': [16],
#                    'reg_alpha': [16],
#                    'reg_lambda': [16]},
#           'tid': 16,
#           'vals': {'bagging_fraction': [0.7043989867564193],
#                    'bagging_freq': [3],
#                    'feature_fraction': [0.7426364119286673],
#                    'learning_rate': [0.11529929936080305],
#                    'max_bin': [0],
#                    'num_leaves': [1],
#                    'reg_alpha': [0.06520744148913293],
#                    'reg_lambda': [0.1835503397619924]},
#           'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2018, 7, 20, 13, 51, 12, 557000),
#  'result': {'loss': 0.28372018885127026, 'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 16,
#  'version': 0}
# {'book_time': datetime.datetime(2018, 7, 20, 13, 51, 12, 562000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#           'idxs': {'bagging_fraction': [17],
#                    'bagging_freq': [17],
#                    'feature_fraction': [17],
#                    'learning_rate': [17],
#                    'max_bin': [17],
#                    'num_leaves': [17],
#                    'reg_alpha': [17],
#                    'reg_lambda': [17]},
#           'tid': 17,
#           'vals': {'bagging_fraction': [0.8541314034934189],
#                    'bagging_freq': [1],
#                    'feature_fraction': [0.871170992744329],
#                    'learning_rate': [0.0766440255010448],
#                    'max_bin': [0],
#                    'num_leaves': [1],
#                    'reg_alpha': [0.057158338719975915],
#                    'reg_lambda': [0.5681590738523481]},
#           'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2018, 7, 20, 13, 51, 15, 551000),
#  'result': {'loss': 0.283048624890483, 'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 17,
#  'version': 0}
# {'book_time': datetime.datetime(2018, 7, 20, 13, 51, 15, 556000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#           'idxs': {'bagging_fraction': [18],
#                    'bagging_freq': [18],
#                    'feature_fraction': [18],
#                    'learning_rate': [18],
#                    'max_bin': [18],
#                    'num_leaves': [18],
#                    'reg_alpha': [18],
#                    'reg_lambda': [18]},
#           'tid': 18,
#           'vals': {'bagging_fraction': [0.885870347766784],
#                    'bagging_freq': [4],
#                    'feature_fraction': [0.6239717809340694],
#                    'learning_rate': [0.12384788908672932],
#                    'max_bin': [1],
#                    'num_leaves': [1],
#                    'reg_alpha': [0.07833151236349863],
#                    'reg_lambda': [0.38656097772543063]},
#           'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2018, 7, 20, 13, 51, 18, 302000),
#  'result': {'loss': 0.2810695769886982, 'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 18,
#  'version': 0}
# {'book_time': datetime.datetime(2018, 7, 20, 13, 51, 18, 307000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#           'idxs': {'bagging_fraction': [19],
#                    'bagging_freq': [19],
#                    'feature_fraction': [19],
#                    'learning_rate': [19],
#                    'max_bin': [19],
#                    'num_leaves': [19],
#                    'reg_alpha': [19],
#                    'reg_lambda': [19]},
#           'tid': 19,
#           'vals': {'bagging_fraction': [0.598167936633302],
#                    'bagging_freq': [2],
#                    'feature_fraction': [0.8304521799368763],
#                    'learning_rate': [0.26744912744201116],
#                    'max_bin': [0],
#                    'num_leaves': [0],
#                    'reg_alpha': [0.18704738264154314],
#                    'reg_lambda': [0.5270714436222745]},
#           'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2018, 7, 20, 13, 51, 23, 60000),
#  'result': {'loss': 0.28909150749763823, 'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 19,
#  'version': 0}
# {'book_time': datetime.datetime(2018, 7, 20, 13, 51, 23, 72000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#           'idxs': {'bagging_fraction': [20],
#                    'bagging_freq': [20],
#                    'feature_fraction': [20],
#                    'learning_rate': [20],
#                    'max_bin': [20],
#                    'num_leaves': [20],
#                    'reg_alpha': [20],
#                    'reg_lambda': [20]},
#           'tid': 20,
#           'vals': {'bagging_fraction': [0.8160644287273675],
#                    'bagging_freq': [4],
#                    'feature_fraction': [0.5015677481061447],
#                    'learning_rate': [0.28934181852375085],
#                    'max_bin': [1],
#                    'num_leaves': [1],
#                    'reg_alpha': [0.11159531860614816],
#                    'reg_lambda': [0.10317274477744195]},
#           'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2018, 7, 20, 13, 51, 25, 659000),
#  'result': {'loss': 0.2821084364480263, 'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 20,
#  'version': 0}
# {'book_time': datetime.datetime(2018, 7, 20, 13, 51, 25, 671000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#           'idxs': {'bagging_fraction': [21],
#                    'bagging_freq': [21],
#                    'feature_fraction': [21],
#                    'learning_rate': [21],
#                    'max_bin': [21],
#                    'num_leaves': [21],
#                    'reg_alpha': [21],
#                    'reg_lambda': [21]},
#           'tid': 21,
#           'vals': {'bagging_fraction': [0.9982898826451438],
#                    'bagging_freq': [4],
#                    'feature_fraction': [0.5303312729464397],
#                    'learning_rate': [0.20971216358340433],
#                    'max_bin': [1],
#                    'num_leaves': [1],
#                    'reg_alpha': [0.1325435434540706],
#                    'reg_lambda': [0.2803600557001521]},
#           'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2018, 7, 20, 13, 51, 28, 820000),
#  'result': {'loss': 0.2804450297153378, 'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 21,
#  'version': 0}
# {'book_time': datetime.datetime(2018, 7, 20, 13, 51, 28, 833000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#           'idxs': {'bagging_fraction': [22],
#                    'bagging_freq': [22],
#                    'feature_fraction': [22],
#                    'learning_rate': [22],
#                    'max_bin': [22],
#                    'num_leaves': [22],
#                    'reg_alpha': [22],
#                    'reg_lambda': [22]},
#           'tid': 22,
#           'vals': {'bagging_fraction': [0.9877257868144054],
#                    'bagging_freq': [4],
#                    'feature_fraction': [0.5175333615531184],
#                    'learning_rate': [0.20682720492459575],
#                    'max_bin': [1],
#                    'num_leaves': [1],
#                    'reg_alpha': [0.12913195382186476],
#                    'reg_lambda': [0.2879176435632232]},
#           'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2018, 7, 20, 13, 51, 31, 544000),
#  'result': {'loss': 0.2803155493130037, 'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 22,
#  'version': 0}
# {'book_time': datetime.datetime(2018, 7, 20, 13, 51, 31, 556000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#           'idxs': {'bagging_fraction': [23],
#                    'bagging_freq': [23],
#                    'feature_fraction': [23],
#                    'learning_rate': [23],
#                    'max_bin': [23],
#                    'num_leaves': [23],
#                    'reg_alpha': [23],
#                    'reg_lambda': [23]},
#           'tid': 23,
#           'vals': {'bagging_fraction': [0.9984014732649594],
#                    'bagging_freq': [4],
#                    'feature_fraction': [0.5038056902440401],
#                    'learning_rate': [0.19975924178652588],
#                    'max_bin': [1],
#                    'num_leaves': [1],
#                    'reg_alpha': [0.13964954073229685],
#                    'reg_lambda': [0.29213522563086347]},
#           'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2018, 7, 20, 13, 51, 34, 367000),
#  'result': {'loss': 0.28002706748977857, 'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 23,
#  'version': 0}
# {'book_time': datetime.datetime(2018, 7, 20, 13, 51, 34, 380000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#           'idxs': {'bagging_fraction': [24],
#                    'bagging_freq': [24],
#                    'feature_fraction': [24],
#                    'learning_rate': [24],
#                    'max_bin': [24],
#                    'num_leaves': [24],
#                    'reg_alpha': [24],
#                    'reg_lambda': [24]},
#           'tid': 24,
#           'vals': {'bagging_fraction': [0.9619486705974865],
#                    'bagging_freq': [4],
#                    'feature_fraction': [0.5049427281219647],
#                    'learning_rate': [0.19133939360565122],
#                    'max_bin': [1],
#                    'num_leaves': [1],
#                    'reg_alpha': [0.1298571341467709],
#                    'reg_lambda': [0.293556725234887]},
#           'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2018, 7, 20, 13, 51, 37, 431000),
#  'result': {'loss': 0.28085010256220083, 'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 24,
#  'version': 0}
# {'book_time': datetime.datetime(2018, 7, 20, 13, 51, 37, 443000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#           'idxs': {'bagging_fraction': [25],
#                    'bagging_freq': [25],
#                    'feature_fraction': [25],
#                    'learning_rate': [25],
#                    'max_bin': [25],
#                    'num_leaves': [25],
#                    'reg_alpha': [25],
#                    'reg_lambda': [25]},
#           'tid': 25,
#           'vals': {'bagging_fraction': [0.8016000845623608],
#                    'bagging_freq': [4],
#                    'feature_fraction': [0.5207570349048238],
#                    'learning_rate': [0.2976018096270486],
#                    'max_bin': [1],
#                    'num_leaves': [1],
#                    'reg_alpha': [0.13839542102061844],
#                    'reg_lambda': [0.11412253642024595]},
#           'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2018, 7, 20, 13, 51, 40, 171000),
#  'result': {'loss': 0.28218120641996486, 'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 25,
#  'version': 0}
# {'book_time': datetime.datetime(2018, 7, 20, 13, 51, 40, 183000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#           'idxs': {'bagging_fraction': [26],
#                    'bagging_freq': [26],
#                    'feature_fraction': [26],
#                    'learning_rate': [26],
#                    'max_bin': [26],
#                    'num_leaves': [26],
#                    'reg_alpha': [26],
#                    'reg_lambda': [26]},
#           'tid': 26,
#           'vals': {'bagging_fraction': [0.996445492235592],
#                    'bagging_freq': [4],
#                    'feature_fraction': [0.553750676360411],
#                    'learning_rate': [0.18809650473469092],
#                    'max_bin': [1],
#                    'num_leaves': [1],
#                    'reg_alpha': [0.10310055714821792],
#                    'reg_lambda': [0.27338177018106946]},
#           'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2018, 7, 20, 13, 51, 42, 959000),
#  'result': {'loss': 0.2804564259879464, 'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 26,
#  'version': 0}
# {'book_time': datetime.datetime(2018, 7, 20, 13, 51, 42, 971000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#           'idxs': {'bagging_fraction': [27],
#                    'bagging_freq': [27],
#                    'feature_fraction': [27],
#                    'learning_rate': [27],
#                    'max_bin': [27],
#                    'num_leaves': [27],
#                    'reg_alpha': [27],
#                    'reg_lambda': [27]},
#           'tid': 27,
#           'vals': {'bagging_fraction': [0.9507731015970734],
#                    'bagging_freq': [4],
#                    'feature_fraction': [0.5460895967899827],
#                    'learning_rate': [0.14641107171397374],
#                    'max_bin': [1],
#                    'num_leaves': [1],
#                    'reg_alpha': [0.1727296655401105],
#                    'reg_lambda': [0.1497418049249116]},
#           'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2018, 7, 20, 13, 51, 45, 799000),
#  'result': {'loss': 0.28084483933064514, 'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 27,
#  'version': 0}
# {'book_time': datetime.datetime(2018, 7, 20, 13, 51, 45, 812000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#           'idxs': {'bagging_fraction': [28],
#                    'bagging_freq': [28],
#                    'feature_fraction': [28],
#                    'learning_rate': [28],
#                    'max_bin': [28],
#                    'num_leaves': [28],
#                    'reg_alpha': [28],
#                    'reg_lambda': [28]},
#           'tid': 28,
#           'vals': {'bagging_fraction': [0.8211331249000892],
#                    'bagging_freq': [4],
#                    'feature_fraction': [0.6949012170156266],
#                    'learning_rate': [0.22683062673477178],
#                    'max_bin': [1],
#                    'num_leaves': [1],
#                    'reg_alpha': [0.14623866398525606],
#                    'reg_lambda': [0.3173760837216703]},
#           'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2018, 7, 20, 13, 51, 48, 554000),
#  'result': {'loss': 0.2825638607408062, 'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 28,
#  'version': 0}
# {'book_time': datetime.datetime(2018, 7, 20, 13, 51, 48, 567000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#           'idxs': {'bagging_fraction': [29],
#                    'bagging_freq': [29],
#                    'feature_fraction': [29],
#                    'learning_rate': [29],
#                    'max_bin': [29],
#                    'num_leaves': [29],
#                    'reg_alpha': [29],
#                    'reg_lambda': [29]},
#           'tid': 29,
#           'vals': {'bagging_fraction': [0.7682715701331422],
#                    'bagging_freq': [4],
#                    'feature_fraction': [0.7977629105366848],
#                    'learning_rate': [0.17591417704225842],
#                    'max_bin': [1],
#                    'num_leaves': [1],
#                    'reg_alpha': [0.12531443526834943],
#                    'reg_lambda': [0.44409443186630826]},
#           'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2018, 7, 20, 13, 51, 51, 228000),
#  'result': {'loss': 0.28334847589143397, 'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 29,
#  'version': 0}

# %%
d_train = lgb.Dataset(x_train, y_train, feature_name=x_names, categorical_feature=categorical)
d_test = lgb.Dataset(x_test, y_test, reference=d_train)

params_best = ho.space_eval(params_space, best)
params = dict(**params_best, **{
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': ['binary_logloss', 'auc'],
    'seed': 430,
})

scores = lgb.cv(params, d_train, nfold=5, num_boost_round=1000, early_stopping_rounds=20)
pd.DataFrame(scores)
# Out:
# /home/ggg/.virtualenvs/forest/lib/python3.6/site-packages/lightgbm/basic.py:1040: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
#     auc-mean  auc-stdv  binary_logloss-mean  binary_logloss-stdv
# 0   0.889332  0.006206             0.447191             0.003017
# 1   0.902450  0.005538             0.410873             0.003451
# 2   0.906406  0.004678             0.376472             0.004285
# 3   0.914219  0.005494             0.355118             0.004990
# 4   0.916281  0.004964             0.338611             0.005214
# 5   0.917507  0.005535             0.327699             0.006075
# 6   0.918322  0.006006             0.317400             0.007007
# 7   0.918907  0.005928             0.312522             0.007266
# 8   0.919666  0.005605             0.308254             0.007291
# 9   0.920318  0.005595             0.305248             0.007530
# 10  0.920634  0.005688             0.302606             0.007761
# 11  0.921649  0.005302             0.298271             0.007644
# 12  0.922074  0.005250             0.296485             0.007719
# 13  0.922857  0.005115             0.293671             0.007703
# 14  0.923483  0.005248             0.291385             0.007978
# 15  0.923775  0.005305             0.290473             0.008080
# 16  0.924124  0.005276             0.289362             0.008104
# 17  0.924456  0.005283             0.288401             0.008175
# 18  0.924876  0.005172             0.287006             0.008109
# 19  0.925040  0.005201             0.286014             0.008190
# 20  0.925222  0.005170             0.285111             0.008251
# 21  0.925158  0.005203             0.285033             0.008312
# 22  0.925521  0.005129             0.284026             0.008251
# 23  0.925786  0.005056             0.283237             0.008206
# 24  0.925881  0.004968             0.282841             0.008109
# 25  0.925998  0.004869             0.282322             0.008020
# 26  0.926041  0.004910             0.282220             0.008062
# 27  0.926089  0.004918             0.281985             0.008067
# 28  0.926152  0.004932             0.281775             0.008114
# 29  0.926183  0.004974             0.281642             0.008191
# 30  0.926220  0.004976             0.281575             0.008221
# 31  0.926269  0.005020             0.281485             0.008242
# 32  0.926349  0.005030             0.281302             0.008290
# 33  0.926329  0.005019             0.281342             0.008246
# 34  0.926468  0.004964             0.280970             0.008261
# 35  0.926441  0.004955             0.280963             0.008285
# 36  0.926501  0.004923             0.280822             0.008250
# 37  0.926554  0.004909             0.280615             0.008256
# 38  0.926665  0.004889             0.280400             0.008287
# 39  0.926711  0.004869             0.280278             0.008265
# 40  0.926784  0.004883             0.280128             0.008301
# 41  0.926717  0.004847             0.280273             0.008259
# 42  0.926707  0.004872             0.280263             0.008300
# 43  0.926727  0.004891             0.280234             0.008315
# 44  0.926769  0.004887             0.280133             0.008306
# 45  0.926733  0.004972             0.280192             0.008432
# 46  0.926747  0.004954             0.280153             0.008408
# 47  0.926745  0.005024             0.280201             0.008507
# 48  0.926770  0.004993             0.280101             0.008474
# 49  0.926844  0.004999             0.279969             0.008547
# 50  0.926872  0.005010             0.279915             0.008561

# %%
from sklearn.model_selection import train_test_split

x0, x1, y0, y1 = train_test_split(x_train, y_train, train_size=.8, random_state=430)

d_train = lgb.Dataset(x0, y0, feature_name=x_names, categorical_feature=categorical)
d_valid = lgb.Dataset(x1, y1, reference=d_train)
# d_test = lgb.Dataset(x_test, y_test, reference=d_train)
# Out:
# /home/ggg/.virtualenvs/forest/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
model = lgb.train(params, d_train, num_boost_round=50, valid_sets=d_valid, valid_names='valid')
# Out:
# /home/ggg/.virtualenvs/forest/lib/python3.6/site-packages/lightgbm/basic.py:1040: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# /home/ggg/.virtualenvs/forest/lib/python3.6/site-packages/lightgbm/basic.py:1042: UserWarning: categorical_feature in Dataset is overridden. New categorical_feature is ['AgeGroup', 'Education', 'MaritalStatus', 'Occupation', 'Race', 'Relationship', 'Sex', 'Workclass']
#   warnings.warn('categorical_feature in Dataset is overridden. New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /home/ggg/.virtualenvs/forest/lib/python3.6/site-packages/lightgbm/basic.py:685: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# [1]	valid's auc: 0.890681	valid's binary_logloss: 0.445437
# [2]	valid's auc: 0.903828	valid's binary_logloss: 0.408681
# [3]	valid's auc: 0.907508	valid's binary_logloss: 0.3745
# [4]	valid's auc: 0.915302	valid's binary_logloss: 0.352839
# [5]	valid's auc: 0.916771	valid's binary_logloss: 0.337172
# [6]	valid's auc: 0.917643	valid's binary_logloss: 0.326646
# [7]	valid's auc: 0.918986	valid's binary_logloss: 0.316227
# [8]	valid's auc: 0.919388	valid's binary_logloss: 0.311633
# [9]	valid's auc: 0.919747	valid's binary_logloss: 0.307595
# [10]	valid's auc: 0.920227	valid's binary_logloss: 0.304779
# [11]	valid's auc: 0.920395	valid's binary_logloss: 0.302221
# [12]	valid's auc: 0.921409	valid's binary_logloss: 0.298096
# [13]	valid's auc: 0.921627	valid's binary_logloss: 0.296539
# [14]	valid's auc: 0.922291	valid's binary_logloss: 0.294112
# [15]	valid's auc: 0.922958	valid's binary_logloss: 0.291741
# [16]	valid's auc: 0.923342	valid's binary_logloss: 0.290767
# [17]	valid's auc: 0.923658	valid's binary_logloss: 0.289534
# [18]	valid's auc: 0.923881	valid's binary_logloss: 0.28864
# [19]	valid's auc: 0.924111	valid's binary_logloss: 0.287836
# [20]	valid's auc: 0.924354	valid's binary_logloss: 0.286783
# [21]	valid's auc: 0.924451	valid's binary_logloss: 0.286163
# [22]	valid's auc: 0.924426	valid's binary_logloss: 0.286185
# [23]	valid's auc: 0.924566	valid's binary_logloss: 0.285645
# [24]	valid's auc: 0.924972	valid's binary_logloss: 0.284765
# [25]	valid's auc: 0.924976	valid's binary_logloss: 0.28444
# [26]	valid's auc: 0.92512	valid's binary_logloss: 0.284179
# [27]	valid's auc: 0.925024	valid's binary_logloss: 0.284154
# [28]	valid's auc: 0.925125	valid's binary_logloss: 0.283762
# [29]	valid's auc: 0.925354	valid's binary_logloss: 0.283378
# [30]	valid's auc: 0.925437	valid's binary_logloss: 0.283109
# [31]	valid's auc: 0.925515	valid's binary_logloss: 0.28294
# [32]	valid's auc: 0.925522	valid's binary_logloss: 0.282861
# [33]	valid's auc: 0.92552	valid's binary_logloss: 0.282915
# [34]	valid's auc: 0.925453	valid's binary_logloss: 0.282906
# [35]	valid's auc: 0.925628	valid's binary_logloss: 0.282532
# [36]	valid's auc: 0.925709	valid's binary_logloss: 0.282306
# [37]	valid's auc: 0.925692	valid's binary_logloss: 0.28223
# [38]	valid's auc: 0.925758	valid's binary_logloss: 0.282039
# [39]	valid's auc: 0.92577	valid's binary_logloss: 0.282136
# [40]	valid's auc: 0.925617	valid's binary_logloss: 0.282395
# [41]	valid's auc: 0.925664	valid's binary_logloss: 0.282312
# [42]	valid's auc: 0.925728	valid's binary_logloss: 0.282154
# [43]	valid's auc: 0.925687	valid's binary_logloss: 0.282212
# [44]	valid's auc: 0.925632	valid's binary_logloss: 0.282305
# [45]	valid's auc: 0.925676	valid's binary_logloss: 0.282289
# [46]	valid's auc: 0.925546	valid's binary_logloss: 0.282453
# [47]	valid's auc: 0.92551	valid's binary_logloss: 0.282456
# [48]	valid's auc: 0.925571	valid's binary_logloss: 0.282385
# [49]	valid's auc: 0.92556	valid's binary_logloss: 0.282503
# [50]	valid's auc: 0.92555	valid's binary_logloss: 0.282525

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([0.00096255, 0.12065365, 0.4335417 , ..., 0.68703336, 0.18318265,
#        0.69140384])

# %%
from sklearn.metrics import log_loss
log_loss(y_test, y_pred)
# Out:
# 0.2814861795096843

# %%
1-.28
# Out:
# 0.72

# %%
params
# Out:
# {'feature_fraction': 0.5001306578388296,
#  'learning_rate': 0.2881638907334713,
#  'max_bin': 255,
#  'num_leaves': 31,
#  'reg_alpha': 0.11987032076957657,
#  'reg_lambda': 0.12012820361026232,
#  'boosting_type': 'gbdt',
#  'objective': 'binary',
#  'metric': ['binary_logloss', 'auc'],
#  'seed': 430,
#  'verbose': 1,
#  'categorical_column': [0, 1, 2, 3, 4, 5, 9, 10]}

# %%
sklearn_params = {
    'seed': 430,
    'n_estimators': 50,
    'learning_rate': 0.2881638907334713,
    'colsample_bytree': 0.5001306578388296,
    'max_bin': 255,
    'num_leaves': 31,
    'reg_alpha': 0.11987032076957657,
    'reg_lambda': 0.12012820361026232,
}
skmodel = lgb.LGBMClassifier(**sklearn_params)
skmodel.fit(x_train, y_train)
skmodel.score(x_test, y_test)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None,
#         colsample_bytree=0.5001306578388296,
#         learning_rate=0.2881638907334713, max_bin=255, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=50, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.11987032076957657,
#         reg_lambda=0.12012820361026232, seed=430, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# /home/ggg/.virtualenvs/forest/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# 0.8708924513236288
